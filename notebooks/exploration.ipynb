# %% [markdown]
# # Battle Cats — Exploratory Analysis
#
# Quick exploration of unit stats and strength scoring.

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from analysis.battle_cats_analysis import (
    sample_data, compute_strength_score, plot_strength_scores, plot_hp_vs_dps
)

# %matplotlib inline
sns.set_theme(style='whitegrid')

# %% [markdown]
# ## 1. Load Data

# %%
# Use sample data for now; replace with load_unit_csv('path/to/data.csv') when ready
df = sample_data()
df.head()

# %% [markdown]
# ## 2. Basic Statistics

# %%
df.describe()

# %% [markdown]
# ## 3. Strength Scoring

# %%
df_scored = compute_strength_score(df)
df_scored[['name', 'hp', 'dps', 'score']].sort_values('score', ascending=False)

# %% [markdown]
# ## 4. Visualisations

# %%
plot_strength_scores(df_scored, top_n=5)

# %%
plot_hp_vs_dps(df_scored)

# %% [markdown]
# ## 5. TODO
#
# - [ ] Load real unit data from CSV / scrape
# - [ ] Expand strength score with more features (range, knockback, special abilities)
# - [ ] Tier list generation
# - [ ] Category / rarity breakdown
